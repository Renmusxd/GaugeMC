# %%
import numpy
from matplotlib import pyplot

# %%
arr = numpy.load("output_loops_nolocal.npz")
ks = arr["ks"]
x = arr["perimeters"]

arr = numpy.load("output_loops_withlocal.npz")
ks_l = arr["ks"]
x_l = arr["perimeters"]

# %%
pyplot.plot(ks, x.mean(axis=0)/(6**4), '.-')
pyplot.plot(ks_l, x_l.mean(axis=0)/(6**4), '.-')
pyplot.grid()
